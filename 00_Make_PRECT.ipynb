# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
## +++ vars in: 
f1_in='f.e.FTORCHmjo_CNTRLmjo_DT.cam.h1.PRECC.1979010100000-1990122200000.nc'
f2_in='f.e.FTORCHmjo_CNTRLmjo_DT.cam.h1.PRECL.1979010100000-1990122200000.nc'
f_out='f.e.FTORCHmjo_CNTRLmjo_DT.cam.h1.PRECT.1979010100000-1990122200000.nc'
dir_in = '/glade/derecho/scratch/wchapman/ADF/f.e.FTORCHmjo_CNTRLmjo_DT/ts/'
## --- vars in: 

file_path = os.path.join(dir_in, f1_in)  # Join the directory and file name
DS = xr.open_dataset(file_path)
file_path = os.path.join(dir_in, f2_in)  # Join the directory and file name
DS2 = xr.open_dataset(file_path)
print('.... adding ...')
DS['PRECT']=DS['PRECC']+DS2['PRECL']
print('.... added ...')
# Copy metadata from PRECC to PRECT
DS['PRECT'].attrs = DS['PRECC'].attrs
# Optional: Update specific attributes if necessary
DS['PRECT'].attrs['long_name'] = 'Total precipitation rate (liq+ic)'
DS['PRECT'].attrs['units'] = 'm/s'  # Ensure the unit is correct for PRECT
DS = DS.drop('PRECC')
print('... saving ...')
DS.to_netcdf(os.path.join(dir_in, f_out))
# Out:
# .... adding ...
# .... added ...
# ... saving ...

# %%
dir_in = '/glade/derecho/scratch/wchapman/ADF/f.e.FTORCHmjo_CNTRLmjo_DT/ts/'
f1_in='f.e.FTORCHmjo_CNTRLmjo_DT.cam.h1.DTCOND.1979010100000-1990122200000.nc'
file_path = os.path.join(dir_in, f1_in)  # Join the directory and file name
DS = xr.open_dataset(file_path)
DS
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 192, lon: 288, lev: 32, ilev: 33, time: 4380, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lev        (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * ilev       (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time       (time) object 1979-01-01 00:00:00 ... 1990-12-31 00:00:00
# Dimensions without coordinates: nbnd
# Data variables:
#     hyam       (lev) float64 ...
#     hybm       (lev) float64 ...
#     P0         float64 ...
#     hyai       (ilev) float64 ...
#     hybi       (ilev) float64 ...
#     time_bnds  (time, nbnd) object ...
#     DTCOND     (time, lev, lat, lon) float64 ...
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              f.e.FTORCHmjo_CNTRLmjo_DT
#     logname:           wchapman
#     host:              derecho3
#     initial_file:      f.e20.FHIST.f09_f09.cesm2_1.001_v2.cam.i.1979-01-01-00...
#     topography_file:   /glade/campaign/cesm/cesmdata/inputdata/atm/cam/topo/f...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  day_1
